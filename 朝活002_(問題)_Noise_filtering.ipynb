# %% [markdown]
# <a href="https://colab.research.google.com/github/Alfaxad/Alfaxad/blob/master/%E6%9C%9D%E6%B4%BB002_(%E5%95%8F%E9%A1%8C)_Noise_filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 使い方
#
# メニューの[File] → [Save a copy in Drive] でファイルをコピーしてから、
# [ctrl] + [F9] またはメニューの[Runtime] → [Run all]を実行してください。
#
# 問題が解けた人は、右上の [share] から [Anyone with the link] を選択し、
# 名前と ファイルのURL を以下のメールアドレスに送ってください。
# レビューをして返答します。
#
# - Alpha+の参加者：greek-academy-info@googlegroups.com
#
# - 外部の参加者：alpha-reviewers@greek-academy.org
#
# -----
#
# メニューの [Tools] → [Settings] → [Editor] から [Show line numbers / Show indentation guides] にチェックを見やすくなります

# %% [markdown]
# # 2023-朝活002. Noise filtering
#
# 0と1で表される画像が2次元配列 (`image`) で与えられます。画像にはノイズが含まれているので、これを取り除きたいです。ノイズは0で囲まれている1の領域です。画像の辺に触れる1の領域は含まれません。
# ノイズの領域を1で塗りつぶしてください。
#
# ---
#
# 条件
# * 1 <= image.length <= 50
# * 1 <= image[0].length <= 50
# *ノイズは、上下左右が0で囲まれている1の領域（斜めは考慮しない）

# %% [markdown]
# ![問題1 (1).png](data:image/png;base64,...)

# %%
#@title 問題を読み込むために、このセクションを実行してください {display-mode: "form"}
from typing import List

# !rm -rf b473fb4e7510975f502b3fdc679e4e82
# !git clone https://gist.github.com/b473fb4e7510975f502b3fdc679e4e82.git
# %reload_ext b473fb4e7510975f502b3fdc679e4e82

# %%
# %%python3_test
# from typing import List, Optional
# # %%python3: python3としてコードを実行します。
# #
# # %%python3_test: python3としてユニットテストを行います。
# # python3_testモードでは solve() 関数を実行します。
#
# def solve(image: List[List[int]]) -> List[List[int]]:

# %%
# %%typescript_test
# /**
#  *  %%typescript: TypeScriptとしてコードを実行します。process.env.NODE_ENV は空です
#  *
#  *  %%typescript_test: TypeScriptとしてユニットテストを行います。process.env.NODE_ENV は 'test' です
#  *
#  *  typescript_testモードでは solve() 関数を実行します。
#  */
# interface IPoint {
#     x: number;
#     y: number;
# }
# export const solve = (image: number[][]): number[][] => {
# }
